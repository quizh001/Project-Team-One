# %%
import pandas as pd

# %%
s1 = pd.Series([1,2,3,4,5,6])
s2 = pd.Series([7,8,9,10,11,12])  
cols = ["A", "C", "D", "E", "F", "G"]

# %%
df = pd.DataFrame([list(s1), list(s2)], columns = cols)
df
# Out:
#    A  C  D   E   F   G
# 0  1  2  3   4   5   6
# 1  7  8  9  10  11  12

# %%
new_row = [13, 14,15, 16,17, 18]

# %%
df.loc[-1] = new_row
df
# Out:
#      A   C   D   E   F   G
#  0   1   2   3   4   5   6
#  1   7   8   9  10  11  12
# -1  13  14  15  16  17  18

# %%
df.reset_index(drop = True, inplace = True)
df
# Out:
#     A   C   D   E   F   G
# 0   1   2   3   4   5   6
# 1   7   8   9  10  11  12
# 2  13  14  15  16  17  18

# %%
new_row1 = [19, 20,21, 22,23, 24]

# %%
df.loc[-1] = new_row1
df
# Out:
#      A   C   D   E   F   G
#  0   1   2   3   4   5   6
#  1   7   8   9  10  11  12
#  2  13  14  15  16  17  18
# -1  19  20  21  22  23  24

# %%
df.reset_index(drop = True, inplace = True,)
df
# Out:
#     A   C   D   E   F   G
# 0   1   2   3   4   5   6
# 1   7   8   9  10  11  12
# 2  13  14  15  16  17  18
# 3  19  20  21  22  23  24

# %%
#call the g a the main
nuevo_data = df
nuevo_data
# Out:
#     A   C   D   E   F   G
# 0   1   2   3   4   5   6
# 1   7   8   9  10  11  12
# 2  13  14  15  16  17  18
# 3  19  20  21  22  23  24

# %%
# Save the dataframe as a csv file
nuevo_data1 = pd.DataFrame(df)
  
# saving the dataframe
nuevo_data1.to_csv('juego.csv')
