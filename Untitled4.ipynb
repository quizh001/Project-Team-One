# %%
import pandas as pd
import sys
import pyreadstat

# %%
print(sys.executable)
# Out:
# /Users/wilsonquizhpi/opt/anaconda3/bin/python

# %%
df = pd.read_spss("primera vuelta.zsav")

# %%
df
# Out:
#                         DIGNIDAD_NOMBRE  PROVINCIA_CODIGO  \
# 0       PRESIDENTA/E Y VICEPRESIDENTA/E               1.0
# 1       PRESIDENTA/E Y VICEPRESIDENTA/E               1.0
# 2       PRESIDENTA/E Y VICEPRESIDENTA/E               1.0
# 3       PRESIDENTA/E Y VICEPRESIDENTA/E               1.0
# 4       PRESIDENTA/E Y VICEPRESIDENTA/E               1.0
# ...                                 ...               ...
# 164963          ASAMBLEÍSTAS NACIONALES              28.0
# 164964          ASAMBLEÍSTAS NACIONALES              28.0
# 164965          ASAMBLEÍSTAS NACIONALES              28.0
# 164966          ASAMBLEÍSTAS NACIONALES              28.0
# 164967          ASAMBLEÍSTAS NACIONALES              28.0
#
#                   PROVINCIA_NOMBRE  CIRCUNSCRIPCION_CODIGO  \
# 0                            AZUAY                     0.0
# 1                            AZUAY                     0.0
# 2                            AZUAY                     0.0
# ...
